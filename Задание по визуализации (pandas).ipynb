# %% [markdown]
# Файл df3.csv находится в архиве с заданием

# %%
# Запустите эту ячейку
import pandas as pd
# %matplotlib inline

df = pd.read_csv('df3.csv')
print(len(df))
print(df.head())
# Out:
# 500
#        weekday  produced  defective
# 0     1.Monday        73          7
# 1    2.Tuesday        75         10
# 2  3.Wednesday        86          7
# 3   4.Thursday        64          7
# 4     5.Friday        70          6

# %% [markdown]
# Эти данные представляют собой заводские производственные показатели и сообщенное количество дефектов в определенные дни недели.

# %% [markdown]
# ### 1. Воссоздайте этот график разброса «произведенных» и «дефектных»  деталей. Обратите внимание на цвет и размер точек. Также обратите внимание на размер картинки. Сможете ли растянуть его аналогичным образом?

# %%
# ВАШ КОД
df.plot.scatter(x ='produced', y = 'defective',sizes = (25,25), color = 'r', figsize =(12,3))
# Out:
# <AxesSubplot:xlabel='produced', ylabel='defective'>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 2. Создайте гистограмму для колонки 'produced'

# %%
# ВАШ КОД
# produced = df['produced']
df['produced'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 3. Перерисуйте гистограмму как на рисунке ниже

# %%
df['produced'].plot.hist(edgecolor = 'k', fontsize =10).autoscale(enable=True, axis = 'x', tight = True) #frontsize - размер шрифта

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 4. Создайте boxplot для 'produced' в каждый из дней недели 'weekday' (используйте группировку)

# %%
df.boxplot('produced',by ='weekday', grid = False )
# Out:
# <AxesSubplot:title={'center':'produced'}, xlabel='weekday'>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 5.Создайте KDE (ядерная оценка плотности) для колонки 'defective'

# %%
df['defective'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 6. Видоизмените график KDE, как на рисунке ниже

# %%
df['defective'].plot.kde(linestyle = '--', lw = 5) #linewidth = lw
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# ### 7. Для первых 30 строк постройте графики областей «произведенных» и «дефектных» деалей. (используйте .loc)

# %%
df.loc[0:30].plot.area(y = ['defective','produced'])
# Out:
# <AxesSubplot:>

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ

# %% [markdown]
# Поменяйте расположение легенды на графике (как показано ниже)

# %%
a = df.loc[0:30].plot.area(y = ['defective','produced']) 
a.legend(bbox_to_anchor=(1.28, 0.6))

# %%
# ОЖИДАЕМЫЙ РЕЗУЛЬТАТ
